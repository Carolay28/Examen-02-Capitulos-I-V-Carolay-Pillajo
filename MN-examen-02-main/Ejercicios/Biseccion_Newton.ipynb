# %% [markdown]
# # Cálculo de raíces usando Bisección y Newton
#
# Se determinan las raíces reales del polinomio de quinto grado
# utilizando métodos numéricos estudiados.

# %%
import numpy as np
from scipy import optimize
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 import numpy as np
# ----> 2 from scipy import optimize
#
# File <frozen importlib._bootstrap>:1423, in _handle_fromlist(module, fromlist, import_, recursive)
#    1420     if not recursive and hasattr(module, '__all__'):
#    1421         _handle_fromlist(module, module.__all__, import_,
#    1422                          recursive=True)
# -> 1423 elif not hasattr(module, x):
#    1424     from_name = f'{module.__name__}.{x}'
#    1425     try:
#
# File c:\Users\karin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\__init__.py:143, in __getattr__(name)
#     141 def __getattr__(name):
#     142     if name in submodules:
# --> 143         return _importlib.import_module(f'scipy.{name}')
#     144     else:
#     145         try:
#
# ...

# %%
def f(x):
    return x**5+5.25*x**4+4.125*x**3-9.125*x**2-14.625*x-5.625

# %%
xs=np.linspace(-5,5,2001)
vals=f(xs)

intervalos=[]
for i in range(len(xs)-1):
    if vals[i]*vals[i+1]<0:
        intervalos.append((xs[i],xs[i+1]))

intervalos

# %%
roots_bisect=[]

for a,b in intervalos:
    r=optimize.bisect(f,a,b)
    roots_bisect.append(r)

roots_bisect

# %%
roots_newton=[]

for r in roots_bisect:
    rn=optimize.newton(f,r)
    roots_newton.append(rn)

roots_newton

# %%
roots_clean=np.unique(np.round(roots_newton,6))
roots_clean=np.sort(roots_clean)
roots_clean

# %%
while len(roots_clean)<6:
    roots_clean=np.append(roots_clean,np.nan)

roots_clean
